# %%
# %pip install kafka-python
# %pip install pandas
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.2.15-py2.py3-none-any.whl.metadata (10.0 kB)
# Downloading kafka_python-2.2.15-py2.py3-none-any.whl (309 kB)
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.2.15
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Using cached pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.conda/lib/python3.8/site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy>=1.20.3 (from pandas)
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.24.4 pandas-2.0.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from kafka import KafkaProducer
import pandas as pd
from json import dumps
from time import sleep

topic_name = 'FloodPrediction'
kafka_server = 'localhost:9092'

producer = KafkaProducer(bootstrap_servers=kafka_server,value_serializer = lambda x:dumps(x).encode('utf-8'))

# Load the CSV file
df = pd.read_csv('dataset/Flood_Features.csv')

# Iterate over rows and send to Kafka
for index, row in df.iterrows():
    data = row.to_dict()
    producer.send(topic_name, value=data)
    print(f"Sent: {data}")
    sleep(5)  # simulate stream (adjust sleep for faster/slower streaming)

producer.flush()
# Out:
# Sent: {'system:index': 19841101, 'date': '11/1/1984', 'rainfall_3day_cumulative_mm': 152.6421066084728, 'rainfall_5day_cumulative_mm': 152.6421066084728, 'rainfall_7day_cumulative_mm': 152.6421066084728, 'rainfall_max_mm': 244.75559997558597, 'rainfall_mean_mm': 152.95928034175105, 'rainfall_std_mm': 33.95694923153398, 'soil_moisture_top10cm_mm': -9999.0, 'subsurface_runoff_mm': -9999.0, 'surface_runoff_mm': -9999.0, '.geo': '{"type":"MultiPoint","coordinates":[]}'}
# Sent: {'system:index': 19841102, 'date': '11/2/1984', 'rainfall_3day_cumulative_mm': 210.656282345948, 'rainfall_5day_cumulative_mm': 210.656282345948, 'rainfall_7day_cumulative_mm': 210.656282345948, 'rainfall_max_mm': 125.19769287109376, 'rainfall_mean_mm': 58.86833630639251, 'rainfall_std_mm': 28.436351361340044, 'soil_moisture_top10cm_mm': -9999.0, 'subsurface_runoff_mm': -9999.0, 'surface_runoff_mm': -9999.0, '.geo': '{"type":"MultiPoint","coordinates":[]}'}
# Sent: {'system:index': 19841103, 'date': '11/3/1984', 'rainfall_3day_cumulative_mm': 220.01269474224827, 'rainfall_5day_cumulative_mm': 220.01269474224827, 'rainfall_7day_cumulative_mm': 220.01269474224827, 'rainfall_max_mm': 37.42907333374024, 'rainfall_mean_mm': 9.759216892734557, 'rainfall_std_mm': 11.83267224009649, 'soil_moisture_top10cm_mm': -9999.0, 'subsurface_runoff_mm': -9999.0, 'surface_runoff_mm': -9999.0, '.geo': '{"type":"MultiPoint","coordinates":[]}'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 19
#      17     producer.send(topic_name, value=data)
#      18     print(f"Sent: {data}")
# ---> 19     sleep(5)  # simulate stream (adjust sleep for faster/slower streaming)
#      21 producer.flush()
#
# KeyboardInterrupt:
